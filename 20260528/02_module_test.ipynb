# %%
import pandas as pd
import yfinance as yf
import invest

# %%
hynix = yf.Ticker('000660.KS')
df = hynix.history(period='10y')
df.head()
# Out:
#                                    Open          High           Low  \
# Date
# 2016-05-30 00:00:00+09:00  25432.091070  25916.931627  25255.785412
# 2016-05-31 00:00:00+09:00  25255.786864  25564.321782  24859.099113
# 2016-06-01 00:00:00+09:00  25432.091547  25564.320792  25035.403810
# 2016-06-02 00:00:00+09:00  25211.705729  25608.393407  24682.788826
# 2016-06-03 00:00:00+09:00  24815.024209  25079.482726  24153.877916
#
#                                   Close   Volume  Dividends  Stock Splits
# Date
# 2016-05-30 00:00:00+09:00  25564.320312  5492886        0.0           0.0
# 2016-05-31 00:00:00+09:00  25299.863281  5414611        0.0           0.0
# 2016-06-01 00:00:00+09:00  25123.556641  3630711        0.0           0.0
# 2016-06-02 00:00:00+09:00  24726.865234  3443745        0.0           0.0
# 2016-06-03 00:00:00+09:00  24330.183594  3680988        0.0           0.0

# %%
inv = invest.Investing(df, _col = 'Close')

# %%
inv.bnh()
# Out:
# np.float64(90.24296252742393)

# %%
mmt_df, mmt_rtn = inv.mmt()
# Out:
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: invalid value encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\Users\hkssn\바탕 화면\multicam\20260528\invest\momentum\__init__.py:54: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i, 'BF1'] / _df2.loc[i, 'BF2'] - _score
# 날짜: 2016-05-31 00:00:00, momentum_index: nan, signal:
# 날짜: 2016-06-30 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-07-29 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-08-31 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-09-30 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-10-31 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-11-30 00:00:00, momentum_index: inf, signal:
# 날짜: 2016-12-29 00:00:00, momentum_index: inf, signal:
# 날짜: 2017-01-31 00:00:00, momentum_index: inf, signal:
# 날짜: 2017-02-28 00:00:00, momentum_index: inf, signal:
# 날짜: 2017-03-31 00:00:00, momentum_index: inf, signal:
# 날짜: 2017-04-28 00:00:00, momentum_index: inf, signal:
# 날짜: 2017-05-31 00:00:00, momentum_index: 0.9065922570913103, signal: buy
# 날짜: 2017-06-30 00:00:00, momentum_index: 0.7826902529114963, signal: buy
# 날짜: 2017-07-31 00:00:00, momentum_index: 0.9853975672058419, signal: buy
# 날짜: 2017-08-31 00:00:00, momentum_index: 0.834816051541784, signal: buy
# 날짜: 2017-09-29 00:00:00, momentum_index: 0.7291957810321934, signal: buy
# 날짜: 2017-10-31 00:00:00, momentum_index: 1.0488800783181063, signal: buy
# 날짜: 2017-11-30 00:00:00, momentum_index: 0.9416036921499258, signal: buy
# 날짜: 2017-12-28 00:00:00, momentum_index: 0.7181209984020511, signal: buy
# 날짜: 2018-01-31 00:00:00, momentum_index: 0.444096134942602, signal: buy
# 날짜: 2018-02-28 00:00:00, momentum_index: 0.5954355795452642, signal: buy
# 날짜: 2018-03-30 00:00:00, momentum_index: 0.541625033132918, signal: buy
# 날짜: 2018-04-30 00:00:00, momentum_index: 0.5261796729170631, signal: buy
# 날짜: 2018-05-31 00:00:00, momentum_index: 0.5027634566849521, signal: buy
# 날짜: 2018-06-29 00:00:00, momentum_index: 0.40473956096288677, signal: buy
# 날짜: 2018-07-31 00:00:00, momentum_index: 0.31627220705040116, signal: buy
# 날짜: 2018-08-31 00:00:00, momentum_index: 0.27525064490340645, signal: buy
# 날짜: 2018-09-28 00:00:00, momentum_index: 0.014921527887820307, signal: buy
# 날짜: 2018-10-31 00:00:00, momentum_index: -0.09852370895687779, signal:
# 날짜: 2018-11-30 00:00:00, momentum_index: -0.09981447846880909, signal:
# 날짜: 2018-12-28 00:00:00, momentum_index: -0.0901962869663524, signal:
# 날짜: 2019-01-31 00:00:00, momentum_index: -0.1558008309665635, signal:
# 날짜: 2019-02-28 00:00:00, momentum_index: -0.013129945523690179, signal:
# 날짜: 2019-03-29 00:00:00, momentum_index: -0.11695211732333455, signal:
# 날짜: 2019-04-30 00:00:00, momentum_index: -0.09941631289369979, signal:
# 날짜: 2019-05-31 00:00:00, momentum_index: -0.13252479169782383, signal:
# 날짜: 2019-06-28 00:00:00, momentum_index: -0.2185356678066005, signal:
# 날짜: 2019-07-31 00:00:00, momentum_index: -0.17405549589870695, signal:
# 날짜: 2019-08-30 00:00:00, momentum_index: -0.049777704782387744, signal:
# 날짜: 2019-09-30 00:00:00, momentum_index: 0.08592628927438617, signal: buy
# 날짜: 2019-10-31 00:00:00, momentum_index: 0.23613062657271922, signal: buy
# 날짜: 2019-11-29 00:00:00, momentum_index: 0.208318739352799, signal: buy
# 날짜: 2019-12-30 00:00:00, momentum_index: 0.3371900788523927, signal: buy
# 날짜: 2020-01-31 00:00:00, momentum_index: 0.2869172989847697, signal: buy
# 날짜: 2020-02-28 00:00:00, momentum_index: 0.3499543985481566, signal: buy
# 날짜: 2020-03-31 00:00:00, momentum_index: 0.19726554794026674, signal: buy
# 날짜: 2020-04-29 00:00:00, momentum_index: 0.0656715705880575, signal: buy
# 날짜: 2020-05-29 00:00:00, momentum_index: 0.29544191156473887, signal: buy
# 날짜: 2020-06-30 00:00:00, momentum_index: 0.18516333480540959, signal: buy
# 날짜: 2020-07-31 00:00:00, momentum_index: 0.11842932631341263, signal: buy
# 날짜: 2020-08-31 00:00:00, momentum_index: 0.08117258160722463, signal: buy
# 날짜: 2020-09-29 00:00:00, momentum_index: -0.07663477410192332, signal:
# 날짜: 2020-10-30 00:00:00, momentum_index: 0.03531111874386261, signal: buy
# 날짜: 2020-11-30 00:00:00, momentum_index: -0.0018316039126903272, signal:
# 날짜: 2020-12-30 00:00:00, momentum_index: 0.03613177245170829, signal: buy
# 날짜: 2021-01-29 00:00:00, momentum_index: 0.28034982702720024, signal: buy
# 날짜: 2021-02-26 00:00:00, momentum_index: 0.40789102254947185, signal: buy
# 날짜: 2021-03-31 00:00:00, momentum_index: 0.7160631698183495, signal: buy
# 날짜: 2021-04-30 00:00:00, momentum_index: 0.5992344780626719, signal: buy
# 날짜: 2021-05-31 00:00:00, momentum_index: 0.5866245327235957, signal: buy
# 날짜: 2021-06-30 00:00:00, momentum_index: 0.5076345782146054, signal: buy
# 날짜: 2021-07-30 00:00:00, momentum_index: 0.5556129345904803, signal: buy
# 날짜: 2021-08-31 00:00:00, momentum_index: 0.513332888515794, signal: buy
# 날짜: 2021-09-30 00:00:00, momentum_index: 0.2808316410121543, signal: buy
# 날짜: 2021-10-29 00:00:00, momentum_index: 0.3023036340721321, signal: buy
# 날짜: 2021-11-30 00:00:00, momentum_index: 0.06722128996743604, signal: buy
# 날짜: 2021-12-30 00:00:00, momentum_index: -0.037974797081714695, signal:
# 날짜: 2022-01-28 00:00:00, momentum_index: 0.08246211648606727, signal: buy
# 날짜: 2022-02-28 00:00:00, momentum_index: -0.13799834303930936, signal:
# 날짜: 2022-03-31 00:00:00, momentum_index: -0.060348669594415205, signal:
# 날짜: 2022-04-29 00:00:00, momentum_index: -0.0645153545134034, signal:
# 날짜: 2022-05-31 00:00:00, momentum_index: -0.10109587697341349, signal:
# 날짜: 2022-06-30 00:00:00, momentum_index: -0.14043589903489329, signal:
# 날짜: 2022-07-29 00:00:00, momentum_index: -0.17657760759646268, signal:
# 날짜: 2022-08-31 00:00:00, momentum_index: -0.06423441015278064, signal:
# 날짜: 2022-09-30 00:00:00, momentum_index: -0.05912133772393824, signal:
# 날짜: 2022-10-31 00:00:00, momentum_index: -0.17566222046590918, signal:
# 날짜: 2022-11-30 00:00:00, momentum_index: -0.2587885864287942, signal:
# 날짜: 2022-12-29 00:00:00, momentum_index: -0.3450447785863102, signal:
# 날짜: 2023-01-31 00:00:00, momentum_index: -0.3692844793612833, signal:
# 날짜: 2023-02-28 00:00:00, momentum_index: -0.2708826936788449, signal:
# 날짜: 2023-03-31 00:00:00, momentum_index: -0.23417822642773456, signal:
# 날짜: 2023-04-28 00:00:00, momentum_index: -0.20116834427904284, signal:
# 날짜: 2023-05-31 00:00:00, momentum_index: -0.15943112568213325, signal:
# 날짜: 2023-06-30 00:00:00, momentum_index: 0.20668311845062082, signal: buy
# 날짜: 2023-07-31 00:00:00, momentum_index: 0.19293272739719192, signal: buy
# 날짜: 2023-08-31 00:00:00, momentum_index: 0.3140874876709583, signal: buy
# 날짜: 2023-09-27 00:00:00, momentum_index: 0.4804195403140983, signal: buy
# 날짜: 2023-10-31 00:00:00, momentum_index: 0.40446711436620153, signal: buy
# 날짜: 2023-11-30 00:00:00, momentum_index: 0.38552514100943136, signal: buy
# 날짜: 2023-12-28 00:00:00, momentum_index: 0.8008504310632893, signal: buy
# 날짜: 2024-01-31 00:00:00, momentum_index: 0.6162078050703803, signal: buy
# 날짜: 2024-02-29 00:00:00, momentum_index: 0.5230496624361758, signal: buy
# 날짜: 2024-03-29 00:00:00, momentum_index: 0.7759445605326099, signal: buy
# 날짜: 2024-04-30 00:00:00, momentum_index: 1.063145182921883, signal: buy
# 날짜: 2024-05-31 00:00:00, momentum_index: 0.6185272687120891, signal: buy
# 날짜: 2024-06-28 00:00:00, momentum_index: 0.6528328855445864, signal: buy
# 날짜: 2024-07-31 00:00:00, momentum_index: 0.9311963024089427, signal: buy
# 날짜: 2024-08-30 00:00:00, momentum_index: 0.6099264583700545, signal: buy
# 날짜: 2024-09-30 00:00:00, momentum_index: 0.522060064048953, signal: buy
# 날짜: 2024-10-31 00:00:00, momentum_index: 0.5114044681160503, signal: buy
# 날짜: 2024-11-29 00:00:00, momentum_index: 0.40071065353457525, signal: buy
# 날짜: 2024-12-30 00:00:00, momentum_index: 0.13522648267558313, signal: buy
# 날짜: 2025-01-31 00:00:00, momentum_index: 0.2969480380193845, signal: buy
# 날짜: 2025-02-28 00:00:00, momentum_index: 0.28114645620709, signal: buy
# 날짜: 2025-03-31 00:00:00, momentum_index: 0.04912937787512006, signal: buy
# 날짜: 2025-04-30 00:00:00, momentum_index: 0.10502536473187418, signal: buy
# 날짜: 2025-05-30 00:00:00, momentum_index: -0.05300666993447467, signal:
# 날짜: 2025-06-30 00:00:00, momentum_index: -0.12669596455414822, signal:
# 날짜: 2025-07-31 00:00:00, momentum_index: 0.5154558264431583, signal: buy
# 날짜: 2025-08-29 00:00:00, momentum_index: 0.5902329157584787, signal: buy
# 날짜: 2025-09-30 00:00:00, momentum_index: 0.5556693599157123, signal: buy
# 날짜: 2025-10-31 00:00:00, momentum_index: 0.8834377458911917, signal: buy
# 날짜: 2025-11-28 00:00:00, momentum_index: 2.5299830934010443, signal: buy
# 날짜: 2025-12-30 00:00:00, momentum_index: 2.0796149901762506, signal: buy
# 날짜: 2026-01-30 00:00:00, momentum_index: 2.3022647427794665, signal: buy
# 날짜: 2026-02-27 00:00:00, momentum_index: 3.798161035809885, signal: buy
# 날짜: 2026-03-31 00:00:00, momentum_index: 4.596116748130991, signal: buy
# 날짜: 2026-04-30 00:00:00, momentum_index: 3.5729583579370496, signal: buy
# 날짜: 2026-05-29 00:00:00, momentum_index: 5.3137304938789836, signal: buy
# 매수일: 2017-05-31 00:00:00, 매수가: 50916.33203125
# 매도일: 2018-10-31 00:00:00, 매도가: 61755.4765625, 수익률: 1.2128814880969323
# 매수일: 2019-09-30 00:00:00, 매수가: 76337.8359375
# 매도일: 2020-09-29 00:00:00, 매도가: 78841.109375, 수익률: 1.0327920408897824
# 매수일: 2020-10-30 00:00:00, 매수가: 74992.921875
# 매도일: 2020-11-30 00:00:00, 매도가: 91512.0, 수익률: 1.2202751634685522
# 매수일: 2020-12-30 00:00:00, 매수가: 112360.5
# 매도일: 2021-12-30 00:00:00, 매도가: 125731.484375, 수익률: 1.119000755381117
# 매수일: 2022-01-28 00:00:00, 매수가: 115653.765625
# 매도일: 2022-02-28 00:00:00, 매도가: 118053.234375, 수익률: 1.0207470006448396
# 매수일: 2023-06-30 00:00:00, 매수가: 112726.9609375
# 매도일: 2025-05-30 00:00:00, 매도가: 203649.015625, 수익률: 1.8065688450335369
# 매수일: 2025-07-31 00:00:00, 매수가: 272361.875

# %%
mmt_rtn
# Out:
# np.float64(3.1542203593590945)
