# %%
# 외부의 모듈을 로드: import 모듈 이름

import mod
# __pycache__ 파일이 자동으로 만들어짐


# from 라이브러리명 import 특정 모듈 (클래스, 함수, 변수)
from mod import Bank

# from ~ import를 사용하는 이유는?
        # 호출 코드 짧게 만들기...?

    # 외부의 라이브러리에서 내가 하는 기능이 20%라 가정할 때,
    # 100%를 로드해서 20%를 사용한다는 것은: import lib
    # 100%에서 30%만 로드해서 20%를 사용한다: from lib import mod
        # 효율적으로는 30%만 로드해놓는 것이 좋다.

# %%
# 모듈 안에 있는 변수를 호출

mod.test_vari
# Out:
# '모듈 안의 변수 데이터'

# %%
# 모듈 안에 있는 함수를 호출

mod.func_1(10, 4)
# Out:
# 14

# %%
# 모듈 안에 클래스 생성

user1 = mod.User('kim', '000301', 0)

# %%
user1.work("A", 40)
# Out:
# 입금이 완료되었습니다. 현재의 잔액은 440000 원 입니다.

# %% [markdown]
# - 모듈: 다른 파일에 있는 변수, 함수, 클래스를 가져다가 쓸 수 있는 기능
#     - 복붙 대비 불필요한 코드들을 없앨 수 있음
#         - 파일을 분할화
#     - 에러를 찾아가는 과정이 빨라짐
#     - 이후 수정 작업에서 모듈 코드 하나만 수정하면 됨
#
# - 팀 프로젝트에서도 모듈화를 신경써주면 좋음
#     - 할 수 있음?ㅠㅠ 라이브러리가 있는데...?
#     - 프로젝트 고도화 기간에 하면 좋다!

# %%
bank1 = Bank('park', '000101')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bank1 = Bank('park', '000101')
#
# NameError: name 'Bank' is not defined
