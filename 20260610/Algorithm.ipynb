# %%
def algorithm(n):
    count = 0

    for i in range(n):
        for j in range(n):
            if i != j:
                count += 1
                print(f'T{i+1} (home) vs T{j+1} (away)')
        
    return count

# %%
algorithm(20)
# Out:
# T1 (home) vs T2 (away)
# T1 (home) vs T3 (away)
# T1 (home) vs T4 (away)
# T1 (home) vs T5 (away)
# T1 (home) vs T6 (away)
# T1 (home) vs T7 (away)
# T1 (home) vs T8 (away)
# T1 (home) vs T9 (away)
# T1 (home) vs T10 (away)
# T1 (home) vs T11 (away)
# T1 (home) vs T12 (away)
# T1 (home) vs T13 (away)
# T1 (home) vs T14 (away)
# T1 (home) vs T15 (away)
# T1 (home) vs T16 (away)
# T1 (home) vs T17 (away)
# T1 (home) vs T18 (away)
# T1 (home) vs T19 (away)
# T1 (home) vs T20 (away)
# T2 (home) vs T1 (away)
# T2 (home) vs T3 (away)
# T2 (home) vs T4 (away)
# T2 (home) vs T5 (away)
# T2 (home) vs T6 (away)
# T2 (home) vs T7 (away)
# T2 (home) vs T8 (away)
# T2 (home) vs T9 (away)
# T2 (home) vs T10 (away)
# T2 (home) vs T11 (away)
# T2 (home) vs T12 (away)
# T2 (home) vs T13 (away)
# T2 (home) vs T14 (away)
# T2 (home) vs T15 (away)
# T2 (home) vs T16 (away)
# T2 (home) vs T17 (away)
# T2 (home) vs T18 (away)
# T2 (home) vs T19 (away)
# T2 (home) vs T20 (away)
# T3 (home) vs T1 (away)
# T3 (home) vs T2 (away)
# T3 (home) vs T4 (away)
# T3 (home) vs T5 (away)
# T3 (home) vs T6 (away)
# T3 (home) vs T7 (away)
# T3 (home) vs T8 (away)
# T3 (home) vs T9 (away)
# T3 (home) vs T10 (away)
# T3 (home) vs T11 (away)
# T3 (home) vs T12 (away)
# T3 (home) vs T13 (away)
# T3 (home) vs T14 (away)
# T3 (home) vs T15 (away)
# T3 (home) vs T16 (away)
# T3 (home) vs T17 (away)
# T3 (home) vs T18 (away)
# T3 (home) vs T19 (away)
# T3 (home) vs T20 (away)
# T4 (home) vs T1 (away)
# T4 (home) vs T2 (away)
# T4 (home) vs T3 (away)
# T4 (home) vs T5 (away)
# T4 (home) vs T6 (away)
# T4 (home) vs T7 (away)
# T4 (home) vs T8 (away)
# T4 (home) vs T9 (away)
# T4 (home) vs T10 (away)
# T4 (home) vs T11 (away)
# T4 (home) vs T12 (away)
# T4 (home) vs T13 (away)
# T4 (home) vs T14 (away)
# T4 (home) vs T15 (away)
# T4 (home) vs T16 (away)
# T4 (home) vs T17 (away)
# T4 (home) vs T18 (away)
# T4 (home) vs T19 (away)
# T4 (home) vs T20 (away)
# T5 (home) vs T1 (away)
# T5 (home) vs T2 (away)
# T5 (home) vs T3 (away)
# T5 (home) vs T4 (away)
# T5 (home) vs T6 (away)
# T5 (home) vs T7 (away)
# T5 (home) vs T8 (away)
# T5 (home) vs T9 (away)
# T5 (home) vs T10 (away)
# T5 (home) vs T11 (away)
# T5 (home) vs T12 (away)
# T5 (home) vs T13 (away)
# T5 (home) vs T14 (away)
# T5 (home) vs T15 (away)
# T5 (home) vs T16 (away)
# T5 (home) vs T17 (away)
# T5 (home) vs T18 (away)
# T5 (home) vs T19 (away)
# T5 (home) vs T20 (away)
# T6 (home) vs T1 (away)
# T6 (home) vs T2 (away)
# T6 (home) vs T3 (away)
# T6 (home) vs T4 (away)
# T6 (home) vs T5 (away)
# T6 (home) vs T7 (away)
# T6 (home) vs T8 (away)
# T6 (home) vs T9 (away)
# T6 (home) vs T10 (away)
# T6 (home) vs T11 (away)
# T6 (home) vs T12 (away)
# T6 (home) vs T13 (away)
# T6 (home) vs T14 (away)
# T6 (home) vs T15 (away)
# T6 (home) vs T16 (away)
# T6 (home) vs T17 (away)
# T6 (home) vs T18 (away)
# T6 (home) vs T19 (away)
# T6 (home) vs T20 (away)
# T7 (home) vs T1 (away)
# T7 (home) vs T2 (away)
# T7 (home) vs T3 (away)
# T7 (home) vs T4 (away)
# T7 (home) vs T5 (away)
# T7 (home) vs T6 (away)
# T7 (home) vs T8 (away)
# T7 (home) vs T9 (away)
# T7 (home) vs T10 (away)
# T7 (home) vs T11 (away)
# T7 (home) vs T12 (away)
# T7 (home) vs T13 (away)
# T7 (home) vs T14 (away)
# T7 (home) vs T15 (away)
# T7 (home) vs T16 (away)
# T7 (home) vs T17 (away)
# T7 (home) vs T18 (away)
# T7 (home) vs T19 (away)
# T7 (home) vs T20 (away)
# T8 (home) vs T1 (away)
# T8 (home) vs T2 (away)
# T8 (home) vs T3 (away)
# T8 (home) vs T4 (away)
# T8 (home) vs T5 (away)
# T8 (home) vs T6 (away)
# T8 (home) vs T7 (away)
# T8 (home) vs T9 (away)
# T8 (home) vs T10 (away)
# T8 (home) vs T11 (away)
# T8 (home) vs T12 (away)
# T8 (home) vs T13 (away)
# T8 (home) vs T14 (away)
# T8 (home) vs T15 (away)
# T8 (home) vs T16 (away)
# T8 (home) vs T17 (away)
# T8 (home) vs T18 (away)
# T8 (home) vs T19 (away)
# T8 (home) vs T20 (away)
# T9 (home) vs T1 (away)
# T9 (home) vs T2 (away)
# T9 (home) vs T3 (away)
# T9 (home) vs T4 (away)
# T9 (home) vs T5 (away)
# T9 (home) vs T6 (away)
# T9 (home) vs T7 (away)
# T9 (home) vs T8 (away)
# T9 (home) vs T10 (away)
# T9 (home) vs T11 (away)
# T9 (home) vs T12 (away)
# T9 (home) vs T13 (away)
# T9 (home) vs T14 (away)
# T9 (home) vs T15 (away)
# T9 (home) vs T16 (away)
# T9 (home) vs T17 (away)
# T9 (home) vs T18 (away)
# T9 (home) vs T19 (away)
# T9 (home) vs T20 (away)
# T10 (home) vs T1 (away)
# T10 (home) vs T2 (away)
# T10 (home) vs T3 (away)
# T10 (home) vs T4 (away)
# T10 (home) vs T5 (away)
# T10 (home) vs T6 (away)
# T10 (home) vs T7 (away)
# T10 (home) vs T8 (away)
# T10 (home) vs T9 (away)
# T10 (home) vs T11 (away)
# T10 (home) vs T12 (away)
# T10 (home) vs T13 (away)
# T10 (home) vs T14 (away)
# T10 (home) vs T15 (away)
# T10 (home) vs T16 (away)
# T10 (home) vs T17 (away)
# T10 (home) vs T18 (away)
# T10 (home) vs T19 (away)
# T10 (home) vs T20 (away)
# T11 (home) vs T1 (away)
# T11 (home) vs T2 (away)
# T11 (home) vs T3 (away)
# T11 (home) vs T4 (away)
# T11 (home) vs T5 (away)
# T11 (home) vs T6 (away)
# T11 (home) vs T7 (away)
# T11 (home) vs T8 (away)
# T11 (home) vs T9 (away)
# T11 (home) vs T10 (away)
# T11 (home) vs T12 (away)
# T11 (home) vs T13 (away)
# T11 (home) vs T14 (away)
# T11 (home) vs T15 (away)
# T11 (home) vs T16 (away)
# T11 (home) vs T17 (away)
# T11 (home) vs T18 (away)
# T11 (home) vs T19 (away)
# T11 (home) vs T20 (away)
# T12 (home) vs T1 (away)
# T12 (home) vs T2 (away)
# T12 (home) vs T3 (away)
# T12 (home) vs T4 (away)
# T12 (home) vs T5 (away)
# T12 (home) vs T6 (away)
# T12 (home) vs T7 (away)
# T12 (home) vs T8 (away)
# T12 (home) vs T9 (away)
# T12 (home) vs T10 (away)
# T12 (home) vs T11 (away)
# T12 (home) vs T13 (away)
# T12 (home) vs T14 (away)
# T12 (home) vs T15 (away)
# T12 (home) vs T16 (away)
# T12 (home) vs T17 (away)
# T12 (home) vs T18 (away)
# T12 (home) vs T19 (away)
# T12 (home) vs T20 (away)
# T13 (home) vs T1 (away)
# T13 (home) vs T2 (away)
# T13 (home) vs T3 (away)
# T13 (home) vs T4 (away)
# T13 (home) vs T5 (away)
# T13 (home) vs T6 (away)
# T13 (home) vs T7 (away)
# T13 (home) vs T8 (away)
# T13 (home) vs T9 (away)
# T13 (home) vs T10 (away)
# T13 (home) vs T11 (away)
# T13 (home) vs T12 (away)
# T13 (home) vs T14 (away)
# T13 (home) vs T15 (away)
# T13 (home) vs T16 (away)
# T13 (home) vs T17 (away)
# T13 (home) vs T18 (away)
# T13 (home) vs T19 (away)
# T13 (home) vs T20 (away)
# T14 (home) vs T1 (away)
# T14 (home) vs T2 (away)
# T14 (home) vs T3 (away)
# T14 (home) vs T4 (away)
# T14 (home) vs T5 (away)
# T14 (home) vs T6 (away)
# T14 (home) vs T7 (away)
# T14 (home) vs T8 (away)
# T14 (home) vs T9 (away)
# T14 (home) vs T10 (away)
# T14 (home) vs T11 (away)
# T14 (home) vs T12 (away)
# T14 (home) vs T13 (away)
# T14 (home) vs T15 (away)
# T14 (home) vs T16 (away)
# T14 (home) vs T17 (away)
# T14 (home) vs T18 (away)
# T14 (home) vs T19 (away)
# T14 (home) vs T20 (away)
# T15 (home) vs T1 (away)
# T15 (home) vs T2 (away)
# T15 (home) vs T3 (away)
# T15 (home) vs T4 (away)
# T15 (home) vs T5 (away)
# T15 (home) vs T6 (away)
# T15 (home) vs T7 (away)
# T15 (home) vs T8 (away)
# T15 (home) vs T9 (away)
# T15 (home) vs T10 (away)
# T15 (home) vs T11 (away)
# T15 (home) vs T12 (away)
# T15 (home) vs T13 (away)
# T15 (home) vs T14 (away)
# T15 (home) vs T16 (away)
# T15 (home) vs T17 (away)
# T15 (home) vs T18 (away)
# T15 (home) vs T19 (away)
# T15 (home) vs T20 (away)
# T16 (home) vs T1 (away)
# T16 (home) vs T2 (away)
# T16 (home) vs T3 (away)
# T16 (home) vs T4 (away)
# T16 (home) vs T5 (away)
# T16 (home) vs T6 (away)
# T16 (home) vs T7 (away)
# T16 (home) vs T8 (away)
# T16 (home) vs T9 (away)
# T16 (home) vs T10 (away)
# T16 (home) vs T11 (away)
# T16 (home) vs T12 (away)
# T16 (home) vs T13 (away)
# T16 (home) vs T14 (away)
# T16 (home) vs T15 (away)
# T16 (home) vs T17 (away)
# T16 (home) vs T18 (away)
# T16 (home) vs T19 (away)
# T16 (home) vs T20 (away)
# T17 (home) vs T1 (away)
# T17 (home) vs T2 (away)
# T17 (home) vs T3 (away)
# T17 (home) vs T4 (away)
# T17 (home) vs T5 (away)
# T17 (home) vs T6 (away)
# T17 (home) vs T7 (away)
# T17 (home) vs T8 (away)
# T17 (home) vs T9 (away)
# T17 (home) vs T10 (away)
# T17 (home) vs T11 (away)
# T17 (home) vs T12 (away)
# T17 (home) vs T13 (away)
# T17 (home) vs T14 (away)
# T17 (home) vs T15 (away)
# T17 (home) vs T16 (away)
# T17 (home) vs T18 (away)
# T17 (home) vs T19 (away)
# T17 (home) vs T20 (away)
# T18 (home) vs T1 (away)
# T18 (home) vs T2 (away)
# T18 (home) vs T3 (away)
# T18 (home) vs T4 (away)
# T18 (home) vs T5 (away)
# T18 (home) vs T6 (away)
# T18 (home) vs T7 (away)
# T18 (home) vs T8 (away)
# T18 (home) vs T9 (away)
# T18 (home) vs T10 (away)
# T18 (home) vs T11 (away)
# T18 (home) vs T12 (away)
# T18 (home) vs T13 (away)
# T18 (home) vs T14 (away)
# T18 (home) vs T15 (away)
# T18 (home) vs T16 (away)
# T18 (home) vs T17 (away)
# T18 (home) vs T19 (away)
# T18 (home) vs T20 (away)
# T19 (home) vs T1 (away)
# T19 (home) vs T2 (away)
# T19 (home) vs T3 (away)
# T19 (home) vs T4 (away)
# T19 (home) vs T5 (away)
# T19 (home) vs T6 (away)
# T19 (home) vs T7 (away)
# T19 (home) vs T8 (away)
# T19 (home) vs T9 (away)
# T19 (home) vs T10 (away)
# T19 (home) vs T11 (away)
# T19 (home) vs T12 (away)
# T19 (home) vs T13 (away)
# T19 (home) vs T14 (away)
# T19 (home) vs T15 (away)
# T19 (home) vs T16 (away)
# T19 (home) vs T17 (away)
# T19 (home) vs T18 (away)
# T19 (home) vs T20 (away)
# T20 (home) vs T1 (away)
# T20 (home) vs T2 (away)
# T20 (home) vs T3 (away)
# T20 (home) vs T4 (away)
# T20 (home) vs T5 (away)
# T20 (home) vs T6 (away)
# T20 (home) vs T7 (away)
# T20 (home) vs T8 (away)
# T20 (home) vs T9 (away)
# T20 (home) vs T10 (away)
# T20 (home) vs T11 (away)
# T20 (home) vs T12 (away)
# T20 (home) vs T13 (away)
# T20 (home) vs T14 (away)
# T20 (home) vs T15 (away)
# T20 (home) vs T16 (away)
# T20 (home) vs T17 (away)
# T20 (home) vs T18 (away)
# T20 (home) vs T19 (away)
# 380

# %%
from linkedlist import LinkedList

# %%
ll = LinkedList()

# %%
ll.insert(0, 1000)

# %%
ll.insert(0, 500)

# %%
ll.print_list()
# Out:
# 500 → 1000 → None

# %%
ll.delete(1)

# %%
ll.print_list()
# Out:
# 500 → None

# %%
ll.get(0)
# Out:
# 500

# %%
ll.update(0, 300)

# %%
ll.get(0)
# Out:
# 300

# %%
arr = [0, 1, 1, 2, 2, 3]
k = 3

# %%
def solution(arr, k):
    answer = []
    for data in arr:
        if data not in answer:
            answer.append(data)
            if len(answer) == k:
                return answer
    while len(answer) < k:
        answer.append(-1)
    
    return answer

# %%
solution(arr, k)
# Out:
# [0, 1, 2]

# %% [markdown]
# 문제 설명
# 숫자로 이루어진 문자열 t와 p가 주어질 때, t에서 p와 길이가 같은 부분문자열 중에서, 이 부분문자열이 나타내는 수가 p가 나타내는 수보다 작거나 같은 것이 나오는 횟수를 return하는 함수 solution을 완성하세요.
#
# 예를 들어, t="3141592"이고 p="271" 인 경우, t의 길이가 3인 부분 문자열은 314, 141, 415, 159, 592입니다. 이 문자열이 나타내는 수 중 271보다 작거나 같은 수는 141, 159 2개 입니다.

# %%
t = "3141592"
p = '271'

# %%
def solution(t, p):
    answer = 0
    for i in range(len(t)-len(p)+1):
        if int(t[i:i+len(p)]) <= int(p):
            answer += 1
    return answer

# %% [markdown]
# 문제 설명
# 정수로 이루어진 배열 numbers가 있습니다. 배열 의 각 원소들에 대해 자신보다 뒤에 있는 숫자 중에서 자신보다 크면서 가장 가까이 있는 수를 뒷 큰수라고 합니다.
# 정수 배열 numbers가 매개변수로 주어질 때, 모든 원소에 대한 뒷 큰수들을 차례로 담은 배열을 return 하도록 solution 함수를 완성해주세요. 단, 뒷 큰수가 존재하지 않는 원소는 -1을 담습니다.

# %%
def solution(numbers):
    answer = [-1] * len(numbers)
    for i in range(len(numbers) - 1):
        for j in range(i+1, len(numbers)):
            if numbers[j] > numbers[i]:
                answer[i] = numbers[j]
                break
    return answer

# %% [markdown]
# ↑ 이 함수는 동작되지만 numbers의 길이가 커지면 시간을 감당하지 못함

# %%
def solution(numbers):
    stack = []
    answer = [-1] * len(numbers)
    
    for i in range(len(numbers) - 1, -1, -1):
        while stack and stack[-1] <= numbers[i]:
            stack.pop()
        if stack:
            answer[i] = stack[-1]
        stack.append(numbers[i])
    return answer

# %% [markdown]
# ↑ 이 방식이 데이터의 길이에 구애받지 않음

# %% [markdown]
# 문제 설명
# 철수는 롤케이크를 두 조각으로 잘라서 동생과 한 조각씩 나눠 먹으려고 합니다. 이 롤케이크에는 여러가지 토핑들이 일렬로 올려져 있습니다. 철수와 동생은 롤케이크를 공평하게 나눠먹으려 하는데, 그들은 롤케이크의 크기보다 롤케이크 위에 올려진 토핑들의 종류에 더 관심이 많습니다. 그래서 잘린 조각들의 크기와 올려진 토핑의 개수에 상관없이 각 조각에 동일한 가짓수의 토핑이 올라가면 공평하게 롤케이크가 나누어진 것으로 생각합니다.
#
# 예를 들어, 롤케이크에 4가지 종류의 토핑이 올려져 있다고 합시다. 토핑들을 1, 2, 3, 4와 같이 번호로 표시했을 때, 케이크 위에 토핑들이 [1, 2, 1, 3, 1, 4, 1, 2] 순서로 올려져 있습니다. 만약 세 번째 토핑(1)과 네 번째 토핑(3) 사이를 자르면 롤케이크의 토핑은 [1, 2, 1], [3, 1, 4, 1, 2]로 나뉘게 됩니다. 철수가 [1, 2, 1]이 놓인 조각을, 동생이 [3, 1, 4, 1, 2]가 놓인 조각을 먹게 되면 철수는 두 가지 토핑(1, 2)을 맛볼 수 있지만, 동생은 네 가지 토핑(1, 2, 3, 4)을 맛볼 수 있으므로, 이는 공평하게 나누어진 것이 아닙니다. 만약 롤케이크의 네 번째 토핑(3)과 다섯 번째 토핑(1) 사이를 자르면 [1, 2, 1, 3], [1, 4, 1, 2]로 나뉘게 됩니다. 이 경우 철수는 세 가지 토핑(1, 2, 3)을, 동생도 세 가지 토핑(1, 2, 4)을 맛볼 수 있으므로, 이는 공평하게 나누어진 것입니다. 공평하게 롤케이크를 자르는 방법은 여러가지 일 수 있습니다. 위의 롤케이크를 [1, 2, 1, 3, 1], [4, 1, 2]으로 잘라도 공평하게 나뉩니다. 어떤 경우에는 롤케이크를 공평하게 나누지 못할 수도 있습니다.
#
# 롤케이크에 올려진 토핑들의 번호를 저장한 정수 배열 topping이 매개변수로 주어질 때, 롤케이크를 공평하게 자르는 방법의 수를 return 하도록 solution 함수를 완성해주세요.

# %%
topping = [1, 2, 1, 3, 1, 4, 1, 2]

# %%
def solution(topping):
    answer = 0
    
    for i in range(1, len(topping) - 1):
        left = topping[0:i]
        right = topping[i:]
        
        left = set(left)
        right = set(right)
        
        if len(left) == len(right):
            answer += 1
    return answer

# %% [markdown]
# ↑ 이러면 개느림

# %%
from collections import Counter

def solution(topping):
    answer = 0
    
    left = set()
    right = Counter(topping)
    
    for t in topping:
        left.add(t)
        right[t] -= 1
        if right[t] == 0:
            del right[t]
        
        if len(left) == len(right):
            answer += 1

# %% [markdown]
# ↑ 이러면 빠름

# %% [markdown]
# 문제 설명
# [본 문제는 정확성과 효율성 테스트 각각 점수가 있는 문제입니다.]
#
# 카카오 초등학교의 "니니즈 친구들"이 "라이언" 선생님과 함께 가을 소풍을 가는 중에 징검다리가 있는 개울을 만나서 건너편으로 건너려고 합니다. "라이언" 선생님은 "니니즈 친구들"이 무사히 징검다리를 건널 수 있도록 다음과 같이 규칙을 만들었습니다.
#
# 징검다리는 일렬로 놓여 있고 각 징검다리의 디딤돌에는 모두 숫자가 적혀 있으며 디딤돌의 숫자는 한 번 밟을 때마다 1씩 줄어듭니다.
# 디딤돌의 숫자가 0이 되면 더 이상 밟을 수 없으며 이때는 그 다음 디딤돌로 한번에 여러 칸을 건너 뛸 수 있습니다.
# 단, 다음으로 밟을 수 있는 디딤돌이 여러 개인 경우 무조건 가장 가까운 디딤돌로만 건너뛸 수 있습니다.
# "니니즈 친구들"은 개울의 왼쪽에 있으며, 개울의 오른쪽 건너편에 도착해야 징검다리를 건넌 것으로 인정합니다.
# "니니즈 친구들"은 한 번에 한 명씩 징검다리를 건너야 하며, 한 친구가 징검다리를 모두 건넌 후에 그 다음 친구가 건너기 시작합니다.
#
# 디딤돌에 적힌 숫자가 순서대로 담긴 배열 stones와 한 번에 건너뛸 수 있는 디딤돌의 최대 칸수 k가 매개변수로 주어질 때, 최대 몇 명까지 징검다리를 건널 수 있는지 return 하도록 solution 함수를 완성해주세요.
